# %%
import matplotlib.pyplot as plt
from src.modules.draw import *
fig, ax = plt.subplots(figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
draw_structure(ax, plot=True, drawForces=True, drawConstraints=True, plot_params='u')#, forces_colors=True)
